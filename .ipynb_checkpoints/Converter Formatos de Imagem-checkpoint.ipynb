# %%
#Importando Libs
import numpy as np
from PIL import Image
import cv2

# %%
#Path Definition:
path = 'D:/Google Drive/Github/CV/Conversão de Imagens/'

# %%
#Abrindo a imagem com a biblioteca PIL
img = Image.open(path + 'lenna.jpg')

# %%
#Visualização da Imagem
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x2E47553B4C0>

# %%
#Salvando a Imagem em PNG
img.save(path + 'lenna.png', "PNG")

# %%
#Salvando a Imagem em BMP
img.save(path + 'lenna.bmp', "BMP")
