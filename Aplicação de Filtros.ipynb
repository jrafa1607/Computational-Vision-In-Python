# %%
#Import das Libs
import matplotlib as mpl
import numpy as np
import math
import cv2
from matplotlib import pyplot as plot

# %%
#Import da Imagem do OneDrive
img = cv2.imread('D:/Google Drive/Github/CV/Images/lenna_ruido.jpg')
img2 = cv2.imread('D:/Google Drive/Github/CV/Images/lenna.jpg')

# %%
#Visualização da Imagem com Ruido
plot.imshow(img,cmap='gray')
plot.show()

# %%
#Visualização da Imagem sem Ruido
plot.imshow(img2,cmap='gray')
plot.show()

# %%
#Converte-se a imagem colorida (BRG) para Escalas de Cinza (Img2)
img2=cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
#Criando uma Função para exibir as saídas das conversões:
def image_output():
    plot.imshow(img,cmap='gray');
    plot.show()
    plot.imshow(saida3,cmap='gray');
    plot.show()
    plot.imshow(saida7,cmap='gray');
    plot.show()

# %%
#Aplicaçao do filtro de Média
saida3 = cv2.blur(img,(3,3))
saida7 = cv2.blur(img,(7,7))
image_output()

# %%
#Aplicaçao do filtro de Mediana
saida3 = cv2.medianBlur(img,3)
saida7 = cv2.medianBlur(img,7)
image_output()

# %%
#Aplicaçao do filtro de Gaussiana
saida3 = cv2.GaussianBlur(img,(3,3),0)
saida7 = cv2.GaussianBlur(img,(7,7),0)
image_output()

# %%
#Aplicaçao do filtro Passa-alta (Filtro utilizado para detectar bordas) 
#Inicialmente, é necessário criar uma matriz 3x3, sendo que 8 unidades possuem o valor -1 e o centro possui o valor 8.
matriz = np.ones((3,3),np.float32)*-1
matriz[1][1] = 8
print(matriz)
# Out:
# [[-1. -1. -1.]
#  [-1.  8. -1.]
#  [-1. -1. -1.]]

# %%
#Exibindo as imagens de: entrada e saída
saida = cv2.filter2D(img2,-1,matriz)

plot.imshow(img2,cmap='gray');
plot.show()
plot.imshow(saida,cmap='gray');

# %%
#Enfatização das bordas
#Somatório das imagens de entrada e saída.
saida = saida + img2
plot.imshow(saida,cmap='gray')   
plot.show()
