# %%
#Import das Libs
import matplotlib as mpl
import numpy as np
import math
import cv2
from matplotlib import pyplot as plot

# %%
#Realiza-se o Upload da Imagem para o Google Colab.
#Em seguida, importa-se a imagem

img = cv2.imread('/content/lenna.jpg')

# %%
#Conversão de BGR para RGB + Exibição da Imagem
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plot.imshow(img,cmap='gray')
plot.show()

# %%
#Função para gerar ruídos aleatórios (Matriz com valores Ruidosos)
def sp_noise(image,prob):

    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob

    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

# %%
#Atribuição do ruído na Imagem
noise_img = sp_noise(img,0.05)

# %%
#Visualização da Imagem com Ruído
plot.imshow(noise_img,cmap='gray')
plot.show()
