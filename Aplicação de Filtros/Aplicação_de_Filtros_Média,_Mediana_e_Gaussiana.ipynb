# %%
#Import das Libs
import matplotlib as mpl
import numpy as np
import math
import cv2
from matplotlib import pyplot as plot

# %%
#Realiza-se o Upload da Imagem para o Google Colab.
#Em seguida, importa-se a imagem

img = cv2.imread('/content/lenna.jpg')

# %%
#Visualização da Imagem
plot.imshow(img,cmap='gray')
plot.show()

# %%
#Criando uma Função para exibir as saídas das conversões
def image_output():
    #Saída com um Kernel de valor 3
    plot.imshow(saida3,cmap='gray');
    plot.show()

    #Saída com um Kernel de valor 7
    plot.imshow(saida7,cmap='gray');
    plot.show()

# %%
#Criando uma Função para exportar as Imagens, após a Aplicação dos Filtros:
def image_export():
    cv2.imwrite('D:/Google Drive/Github/CV/Lenna/' + function + 'kernel3x3.jpg', saida3)
    cv2.imwrite('D:/Google Drive/Github/CV/Lenna/' + function + 'kernel7x7.jpg', saida7)

# %%
#Aplicaçao do filtro de Média
function = 'media'
saida3 = cv2.blur(img,(3,3))
saida7 = cv2.blur(img,(7,7))
image_output()
image_export()

# %%
#Aplicaçao do filtro de Mediana
function = 'mediana'
saida3 = cv2.medianBlur(img,(3))
saida7 = cv2.medianBlur(img,(7))
image_output()
image_export()

# %%
#Aplicaçao do filtro de Gaussiana
function = 'gaussiana'
saida3 = cv2.GaussianBlur(img,(3,3),0)
saida7 = cv2.GaussianBlur(img,(7,7),0)
image_output()
image_export()
